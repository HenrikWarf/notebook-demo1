# %% [markdown]
# # Running BigQuery ML with Transformations

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
sb.set()

# %% [markdown]
# ### The Data

# %%
# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# %%bigquery earnings_data
# SELECT *
# FROM `crazy-hippo-01.clv.earnings_per_year`
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/magics/magics.py in _cell_magic(line, query)
#     605         else:
# --> 606             result = query_job.to_dataframe(bqstorage_client=bqstorage_client)
#     607
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/job.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, date_as_object)
#    3405             create_bqstorage_client=create_bqstorage_client,
# -> 3406             date_as_object=date_as_object,
#    3407         )
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/table.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, date_as_object)
#    1727                 bqstorage_client=bqstorage_client,
# -> 1728                 create_bqstorage_client=create_bqstorage_client,
#    1729             )
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/table.py in to_arrow(self, progress_bar_type, bqstorage_client, create_bqstorage_client)
#    1545             for record_batch in self._to_arrow_iterable(
# -> 1546                 bqstorage_client=bqstorage_client
#    1547             ):
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/table.py in _to_page_iterable(self, bqstorage_download, tabledata_list_download, bqstorage_client)
#    1434         if bqstorage_client is not None:
# -> 1435             for item in bqstorage_download():
#    1436                 yield item
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/_pandas_helpers.py in _download_table_bqstorage(project_id, table, bqstorage_client, preserve_order, selected_fields, page_to_item)
#     663             table=table.to_bqstorage(),
# --> 664             data_format=bigquery_storage_v1.enums.DataFormat.ARROW,
#     665         )
#
# AttributeError: module 'google.cloud.bigquery_storage_v1' has no attribute 'enums'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-836e5d4f8d29> in <module>
# ----> 1 get_ipython().run_cell_magic('bigquery', 'earnings_data', 'SELECT *\nFROM `crazy-hippo-01.clv.earnings_per_year`\n')
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2379             with self.builtin_trap:
#    2380                 args = (magic_arg_s, cell)
# -> 2381                 result = fn(*args, **kwargs)
#    2382             return result
#    2383
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/magics/magics.py in _cell_magic(line, query)
#     611             return result
#     612     finally:
# --> 613         close_transports()
#     614
#     615
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/magics/magics.py in _close_transports(client, bqstorage_client)
#     677     client.close()
#     678     if bqstorage_client is not None:
# --> 679         bqstorage_client.transport.channel.close()
#
# AttributeError: 'BigQueryReadGrpcTransport' object has no attribute 'channel'

# %%
earnings_data.head()
# Out:
#    age workclass  fnlwgt education  education_num       marital_status  \
# 0   39   Private  297847       9th              5   Married-civ-spouse
# 1   72   Private   74141       9th              5   Married-civ-spouse
# 2   45   Private  178215       9th              5   Married-civ-spouse
# 3   31   Private   86958       9th              5   Married-civ-spouse
# 4   55   Private  176012       9th              5   Married-civ-spouse
#
#            occupation relationship                 race      sex  \
# 0       Other-service         Wife                Black   Female
# 1     Exec-managerial         Wife   Asian-Pac-Islander   Female
# 2   Machine-op-inspct         Wife                White   Female
# 3     Exec-managerial         Wife                White   Female
# 4        Tech-support         Wife                White   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          3411             0              34   United-States   <=50K
# 1             0             0              48   United-States    >50K
# 2             0             0              40   United-States    >50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              23   United-States   <=50K

# %% [markdown]
# ### Training a model in BQML

# %% [markdown]
# #### Using Logistic Regression and adding a transformation to the data.

# %%
# %%bigquery
# CREATE OR REPLACE MODEL clv.earnings_model
# TRANSFORM(ML.FEATURE_CROSS(STRUCT(marital_status, relationship)) as cross_relationship,
#             * EXCEPT(fnlwgt))
# OPTIONS(input_label_cols=['income'], model_type='logistic_reg')
# AS
# SELECT *
# FROM
#   `crazy-hippo-01.clv.earnings_per_year`
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# The transformation step is stored within the model and will be applied to the data when doing predictions.

# %% [markdown]
# #### Use the <b>ML.EVALUATE</b> function to evaluate model metrics.

# %%
# %%bigquery
# CREATE OR REPLACE TABLE clv.earnings_evaluation AS (
# SELECT
#   *
# FROM
#   ML.EVALUATE(MODEL `crazy-hippo-01.clv.earnings_model`)
# )
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Let us generate som samples to predit on

# %%
# %%bigquery
# CREATE or REPLACE TABLE `clv.prediction_sample`
# AS (
# SELECT *
# FROM `crazy-hippo-01.clv.earnings_per_year`
# WHERE RAND() < 0.0005
# )
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Loading data from BQ and see how the data looks.

# %%
# %%bigquery prediction_data
# SELECT *
# FROM `crazy-hippo-01.clv.prediction_sample`

# %%
prediction_data
# Out:
#     age      workclass  fnlwgt      education  education_num  \
# 0    32        Private  259719   Some-college             10
# 1    42        Private  222011   Some-college             10
# 2    40        Private  106698     Assoc-acdm             12
# 3    40        Private  141537           10th              6
# 4    40      Local-gov  183765     Assoc-acdm             12
# 5    20   Self-emp-inc   95997        HS-grad              9
# 6    22        Private  139190        HS-grad              9
# 7    19        Private   87497           11th              7
# 8    20        Private  375698   Some-college             10
# 9    24        Private  112854   Some-college             10
# 10   34        Private  220840        5th-6th              3
# 11   58        Private  239523        HS-grad              9
# 12   47        Private  157901           11th              7
# 13   43        Private  245056        HS-grad              9
# 14   49      Local-gov   67001        HS-grad              9
#
#          marital_status          occupation     relationship  \
# 0              Divorced   Handlers-cleaners        Unmarried
# 1              Divorced               Sales        Unmarried
# 2              Divorced    Transport-moving        Unmarried
# 3              Divorced   Machine-op-inspct    Not-in-family
# 4         Never-married      Prof-specialty    Not-in-family
# 5         Never-married     Farming-fishing        Own-child
# 6         Never-married        Craft-repair        Own-child
# 7         Never-married    Transport-moving   Other-relative
# 8         Never-married        Adm-clerical        Own-child
# 9         Never-married        Tech-support    Not-in-family
# 10   Married-civ-spouse     Farming-fishing          Husband
# 11   Married-civ-spouse     Exec-managerial          Husband
# 12   Married-civ-spouse       Other-service          Husband
# 13   Married-civ-spouse        Adm-clerical          Husband
# 14   Married-civ-spouse    Transport-moving          Husband
#
#                    race      sex  capital_gain  capital_loss  hours_per_week  \
# 0                 Black     Male             0             0              40
# 1                 White   Female             0             0              43
# 2                 White   Female             0             0              40
# 3                 Black   Female             0             0              40
# 4                 White     Male             0             0              40
# 5                 White     Male             0             0              70
# 6                 White     Male             0             0              50
# 7                 White     Male             0             0              10
# 8                 White   Female             0             0              15
# 9                 White   Female             0             0              16
# 10                White     Male             0             0              40
# 11                White     Male             0             0              45
# 12   Amer-Indian-Eskimo     Male             0             0              36
# 13                Black     Male             0             0              40
# 14                White     Male             0             0              40
#
#     native_country  income
# 0        Nicaragua   <=50K
# 1    United-States   <=50K
# 2    United-States   <=50K
# 3    United-States   <=50K
# 4    United-States    >50K
# 5    United-States   <=50K
# 6    United-States   <=50K
# 7    United-States   <=50K
# 8    United-States   <=50K
# 9    United-States   <=50K
# 10          Mexico   <=50K
# 11   United-States    >50K
# 12   United-States   <=50K
# 13   United-States    >50K
# 14   United-States   <=50K

# %% [markdown]
# #### Batch Predictions

# %%
# %%bigquery
# CREATE TABLE clv.earnings_predictions (
# SELECT *
# FROM
#   ML.PREDICT(MODEL `crazy-hippo-01.clv.earnings_model`,
#     (
#     SELECT
#       *
#     FROM
#       `crazy-hippo-01.clv.prediction_sample`))
# )
# Out:
#    predicted_income                             predicted_income_probs  age  \
# 0             <=50K  [{'label': ' >50K', 'prob': 0.0064679070900027...   18
# 1             <=50K  [{'label': ' >50K', 'prob': 0.0130025858367740...   22
# 2             <=50K  [{'label': ' >50K', 'prob': 0.0352982720717686...   27
# 3              >50K  [{'label': ' >50K', 'prob': 0.519380971495562}...   81
# 4             <=50K  [{'label': ' >50K', 'prob': 0.1626030121338418...   58
# 5              >50K  [{'label': ' >50K', 'prob': 0.8122983535348138...   47
# 6             <=50K  [{'label': ' >50K', 'prob': 0.1808120551673187...   27
# 7             <=50K  [{'label': ' >50K', 'prob': 0.1679548620335508...   43
# 8             <=50K  [{'label': ' >50K', 'prob': 0.0547894170687177...   69
# 9             <=50K  [{'label': ' >50K', 'prob': 0.4647326728675621...   62
# 10            <=50K  [{'label': ' >50K', 'prob': 0.4642267119941572...   40
# 11            <=50K  [{'label': ' >50K', 'prob': 0.2801247812074633...   25
# 12            <=50K  [{'label': ' >50K', 'prob': 0.0213549499964281...   22
# 13            <=50K  [{'label': ' >50K', 'prob': 0.0612750244056497...   44
# 14            <=50K  [{'label': ' >50K', 'prob': 0.0145597895378673...   23
# 15            <=50K  [{'label': ' >50K', 'prob': 0.0131073923445326...   21
#
#             workclass  fnlwgt      education  education_num  \
# 0                   ?  113185           11th              7
# 1             Private  267174        HS-grad              9
# 2    Self-emp-not-inc  107846        HS-grad              9
# 3    Self-emp-not-inc  136063        HS-grad              9
# 4             Private  234213        HS-grad              9
# 5           Local-gov   36169        Masters             14
# 6             Private  128730      Assoc-voc             11
# 7         Federal-gov   92775      Assoc-voc             11
# 8                   ?  180187     Assoc-acdm             12
# 9             Private  159908   Some-college             10
# 10            Private   70539   Some-college             10
# 11            Private  209286   Some-college             10
# 12            Private  222490   Some-college             10
# 13            Private  109273   Some-college             10
# 14            Private  181820   Some-college             10
# 15            Private  197583   Some-college             10
#
#          marital_status          occupation    relationship    race      sex  \
# 0         Never-married                   ?       Own-child   White     Male
# 1         Never-married   Handlers-cleaners       Own-child   Black     Male
# 2         Never-married     Protective-serv   Not-in-family   White     Male
# 3    Married-civ-spouse     Exec-managerial         Husband   White     Male
# 4              Divorced        Craft-repair   Not-in-family   White     Male
# 5    Married-civ-spouse      Prof-specialty         Husband   White     Male
# 6         Never-married     Exec-managerial   Not-in-family   White     Male
# 7              Divorced        Craft-repair   Not-in-family   White     Male
# 8               Widowed                   ?   Not-in-family   White   Female
# 9    Married-civ-spouse        Adm-clerical            Wife   White   Female
# 10   Married-civ-spouse               Sales         Husband   White     Male
# 11   Married-civ-spouse        Craft-repair         Husband   White     Male
# 12        Never-married               Sales       Own-child   White   Female
# 13        Never-married        Craft-repair   Not-in-family   White     Male
# 14        Never-married   Handlers-cleaners       Own-child   White     Male
# 15        Never-married        Adm-clerical       Own-child   White   Female
#
#     capital_gain  capital_loss  hours_per_week  native_country  income
# 0              0             0              25   United-States   <=50K
# 1              0             0              40   United-States   <=50K
# 2              0             0              30   United-States   <=50K
# 3              0             0              30   United-States   <=50K
# 4          14344             0              48   United-States    >50K
# 5              0             0              60   United-States    >50K
# 6          10520             0              65          Greece    >50K
# 7              0             0              40   United-States   <=50K
# 8              0             0               6           Italy   <=50K
# 9              0             0              38   United-States    >50K
# 10          4386             0              50   United-States   <=50K
# 11             0             0              40   United-States   <=50K
# 12             0             0              30   United-States   <=50K
# 13             0             0              38   United-States   <=50K
# 14             0             0              20   United-States   <=50K
# 15             0             0              20   United-States   <=50K
