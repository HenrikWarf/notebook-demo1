# %% [markdown]
# # Running BigQuery ML

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
sb.set()

# %% [markdown]
# ### The Data

# %%
# %%bigquery earnings_data
# SELECT *
# FROM `crazy-hippo-01.clv.earnings_per_year`

# %%
earnings_data.head()
# Out:
#    age workclass  fnlwgt education  education_num       marital_status  \
# 0   39   Private  297847       9th              5   Married-civ-spouse
# 1   72   Private   74141       9th              5   Married-civ-spouse
# 2   45   Private  178215       9th              5   Married-civ-spouse
# 3   31   Private   86958       9th              5   Married-civ-spouse
# 4   55   Private  176012       9th              5   Married-civ-spouse
#
#            occupation relationship                 race      sex  \
# 0       Other-service         Wife                Black   Female
# 1     Exec-managerial         Wife   Asian-Pac-Islander   Female
# 2   Machine-op-inspct         Wife                White   Female
# 3     Exec-managerial         Wife                White   Female
# 4        Tech-support         Wife                White   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          3411             0              34   United-States   <=50K
# 1             0             0              48   United-States    >50K
# 2             0             0              40   United-States    >50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              23   United-States   <=50K

# %% [markdown]
# ### Training a model in BigQuery ML

# %% [markdown]
# #### Using Logistic Regression for this example

# %%
# %%bigquery
# CREATE OR REPLACE MODEL clv.earnings_model
# OPTIONS(input_label_cols=['income'], model_type='logistic_reg')
# AS
# SELECT *
# FROM
#   `crazy-hippo-01.clv.earnings_per_year`
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### The <b>ML.FEATURE_INFO</b> function allows you to see information about the input features used to train a model.

# %%
# %%bigquery
# SELECT *
# FROM ML.FEATURE_INFO(MODEL `crazy-hippo-01.clv.earnings_model`)
# Out:
#              input      min        max           mean    median  \
# 0              age     17.0       90.0      38.580010      37.0
# 1        workclass      NaN        NaN            NaN       NaN
# 2           fnlwgt  13769.0  1484705.0  189622.921468  177951.0
# 3        education      NaN        NaN            NaN       NaN
# 4    education_num      1.0       16.0      10.074694      10.0
# 5   marital_status      NaN        NaN            NaN       NaN
# 6       occupation      NaN        NaN            NaN       NaN
# 7     relationship      NaN        NaN            NaN       NaN
# 8             race      NaN        NaN            NaN       NaN
# 9              sex      NaN        NaN            NaN       NaN
# 10    capital_gain      0.0    99999.0    1091.310981       0.0
# 11    capital_loss      0.0     4356.0      89.779949       0.0
# 12  hours_per_week      1.0       99.0      40.417802      40.0
# 13  native_country      NaN        NaN            NaN       NaN
#
#            stddev  category_count  null_count
# 0       13.667871             NaN         0.0
# 1             NaN             9.0         NaN
# 2   105574.934549             NaN         0.0
# 3             NaN            16.0         NaN
# 4        2.574967             NaN         0.0
# 5             NaN             7.0         NaN
# 6             NaN            15.0         NaN
# 7             NaN             6.0         NaN
# 8             NaN             5.0         NaN
# 9             NaN             2.0         NaN
# 10    7440.157104             NaN         0.0
# 11     409.005093             NaN         0.0
# 12      12.418299             NaN         0.0
# 13            NaN            42.0         NaN

# %% [markdown]
# #### Use the <b>ML.EVALUATE</b> function to evaluate model metrics.

# %%
# %%bigquery
# SELECT
#   *
# FROM
#   ML.EVALUATE(MODEL `crazy-hippo-01.clv.earnings_model`)
# Out:
#    precision    recall  accuracy  f1_score  log_loss  roc_auc
# 0   0.709845  0.540434  0.838483  0.613662  0.347407   0.8898

# %% [markdown]
# #### Use the <b>ML.CONFUSION_MATRIX</b> function to return a confusion matrix for the given logistic regression model and input data.

# %%
# %%bigquery
# SELECT
#   *
# FROM
#   ML.CONFUSION_MATRIX(MODEL `crazy-hippo-01.clv.earnings_model`,
#   (
#     SELECT
#       *
#     FROM
#       `crazy-hippo-01.clv.earnings_per_year`))
# Out:
#   expected_label  ___50K  __50K
# 0          <=50K   23053   1588
# 1           >50K    3522   4298

# %% [markdown]
# #### The <b>ML.WEIGHTS</b> function allows you to see the underlying weights used by a model during prediction.

# %%
# %%bigquery
# SELECT *
# FROM ML.WEIGHTS(MODEL `crazy-hippo-01.clv.earnings_model`
# )
# Out:
#    processed_input        weight  \
# 0              age  1.989957e-02
# 1        workclass           NaN
# 2           fnlwgt  3.201723e-07
# 3        education           NaN
# 4    education_num  1.239920e-01
# 5   marital_status           NaN
# 6       occupation           NaN
# 7     relationship           NaN
# 8             race           NaN
# 9              sex           NaN
# 10    capital_gain  4.762421e-05
# 11    capital_loss  4.775841e-04
# 12  hours_per_week  2.072122e-02
# 13  native_country           NaN
# 14   __INTERCEPT__ -3.207574e+00
#
#                                      category_weights
# 0                                                  []
# 1   [{'category': ' Self-emp-inc', 'weight': 0.332...
# 2                                                  []
# 3   [{'category': ' 7th-8th', 'weight': -0.7002128...
# 4                                                  []
# 5   [{'category': ' Separated', 'weight': -0.60850...
# 6   [{'category': ' Adm-clerical', 'weight': -0.37...
# 7   [{'category': ' Unmarried', 'weight': -0.62860...
# 8   [{'category': ' Black', 'weight': -0.391409798...
# 9   [{'category': ' Male', 'weight': -0.0538525515...
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13  [{'category': ' Thailand', 'weight': -0.662657...
# 14                                                 []

# %% [markdown]
# ## Batch Predictions

# %% [markdown]
# #### Let us generate som samples to predit on

# %%
# %%bigquery
# CREATE or REPLACE TABLE `clv.prediction_sample`
# AS (
# SELECT *
# FROM `crazy-hippo-01.clv.earnings_per_year`
# WHERE RAND() < 0.0005
# )
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Loading data from BQ and see how the data looks.

# %%
# %%bigquery prediction_data
# SELECT *
# FROM `crazy-hippo-01.clv.prediction_sample`

# %%
prediction_data
# Out:
#     age   workclass  fnlwgt      education  education_num  \
# 0    27     Private  160786           11th              7
# 1    46     Private  273629        Masters             14
# 2    36   Local-gov   61778        HS-grad              9
# 3    54     Private  215990        HS-grad              9
# 4    43     Private  397280     Assoc-acdm             12
# 5    26     Private  103700   Some-college             10
# 6    48     Private  232840   Some-college             10
# 7    54     Private  240542   Some-college             10
# 8    32           ?   30499      Bachelors             13
# 9    41     Private  106627     Assoc-acdm             12
# 10   67     Private  134906        HS-grad              9
# 11   33     Private   99339     Assoc-acdm             12
#
#          marital_status        occupation    relationship    race      sex  \
# 0    Married-civ-spouse      Craft-repair         Husband   White     Male
# 1    Married-civ-spouse   Exec-managerial         Husband   White     Male
# 2    Married-civ-spouse    Prof-specialty         Husband   White     Male
# 3    Married-civ-spouse   Exec-managerial         Husband   White     Male
# 4         Never-married    Prof-specialty   Not-in-family   White     Male
# 5         Never-married      Tech-support       Own-child   White   Female
# 6               Widowed      Adm-clerical       Unmarried   White   Female
# 7              Divorced             Sales       Unmarried   White   Female
# 8              Divorced                 ?       Unmarried   White   Female
# 9              Divorced   Exec-managerial       Unmarried   Black   Female
# 10              Widowed             Sales   Not-in-family   White   Female
# 11             Divorced      Adm-clerical   Not-in-family   White   Female
#
#     capital_gain  capital_loss  hours_per_week  native_country  income
# 0              0          1902              40   United-States    >50K
# 1              0             0              40   United-States    >50K
# 2          15024             0              40   United-States    >50K
# 3              0             0              40   United-States    >50K
# 4              0             0              50   United-States    >50K
# 5              0             0              40   United-States   <=50K
# 6              0             0              43   United-States   <=50K
# 7              0             0              48   United-States   <=50K
# 8              0             0              32   United-States   <=50K
# 9              0             0              50   United-States   <=50K
# 10             0             0              32   United-States   <=50K
# 11             0           880              40   United-States   <=50K

# %% [markdown]
# #### Batch Predictions

# %%
# %%bigquery
# SELECT *
# FROM
#   ML.PREDICT(MODEL `crazy-hippo-01.clv.earnings_model`,
#     (
#     SELECT
#       *
#     FROM
#       `crazy-hippo-01.clv.prediction_sample`))
# Out:
#    predicted_income                             predicted_income_probs  age  \
# 0             <=50K  [{'label': ' >50K', 'prob': 0.2975156380809634...   27
# 1              >50K  [{'label': ' >50K', 'prob': 0.7964805186208006...   46
# 2             <=50K  [{'label': ' >50K', 'prob': 0.4897753081576619...   36
# 3              >50K  [{'label': ' >50K', 'prob': 0.501900596261103}...   54
# 4             <=50K  [{'label': ' >50K', 'prob': 0.1638158349601476...   43
# 5             <=50K  [{'label': ' >50K', 'prob': 0.0372807235318270...   26
# 6             <=50K  [{'label': ' >50K', 'prob': 0.0541007905844975...   48
# 7             <=50K  [{'label': ' >50K', 'prob': 0.0906534809283018...   54
# 8             <=50K  [{'label': ' >50K', 'prob': 0.0460866293422405...   32
# 9             <=50K  [{'label': ' >50K', 'prob': 0.1259224686451649...   41
# 10            <=50K  [{'label': ' >50K', 'prob': 0.0657434986545291...   67
# 11            <=50K  [{'label': ' >50K', 'prob': 0.0788050220078543...   33
#
#      workclass  fnlwgt      education  education_num       marital_status  \
# 0      Private  160786           11th              7   Married-civ-spouse
# 1      Private  273629        Masters             14   Married-civ-spouse
# 2    Local-gov   61778        HS-grad              9   Married-civ-spouse
# 3      Private  215990        HS-grad              9   Married-civ-spouse
# 4      Private  397280     Assoc-acdm             12        Never-married
# 5      Private  103700   Some-college             10        Never-married
# 6      Private  232840   Some-college             10              Widowed
# 7      Private  240542   Some-college             10             Divorced
# 8            ?   30499      Bachelors             13             Divorced
# 9      Private  106627     Assoc-acdm             12             Divorced
# 10     Private  134906        HS-grad              9              Widowed
# 11     Private   99339     Assoc-acdm             12             Divorced
#
#           occupation    relationship    race      sex  capital_gain  \
# 0       Craft-repair         Husband   White     Male             0
# 1    Exec-managerial         Husband   White     Male             0
# 2     Prof-specialty         Husband   White     Male         15024
# 3    Exec-managerial         Husband   White     Male             0
# 4     Prof-specialty   Not-in-family   White     Male             0
# 5       Tech-support       Own-child   White   Female             0
# 6       Adm-clerical       Unmarried   White   Female             0
# 7              Sales       Unmarried   White   Female             0
# 8                  ?       Unmarried   White   Female             0
# 9    Exec-managerial       Unmarried   Black   Female             0
# 10             Sales   Not-in-family   White   Female             0
# 11      Adm-clerical   Not-in-family   White   Female             0
#
#     capital_loss  hours_per_week  native_country  income
# 0           1902              40   United-States    >50K
# 1              0              40   United-States    >50K
# 2              0              40   United-States    >50K
# 3              0              40   United-States    >50K
# 4              0              50   United-States    >50K
# 5              0              40   United-States   <=50K
# 6              0              43   United-States   <=50K
# 7              0              48   United-States   <=50K
# 8              0              32   United-States   <=50K
# 9              0              50   United-States   <=50K
# 10             0              32   United-States   <=50K
# 11           880              40   United-States   <=50K
