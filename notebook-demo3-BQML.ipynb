# %% [markdown]
# # Running BigQuery ML

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
sb.set()

# %%
# !pip install --upgrade google-cloud-bigquery

# %% [markdown]
# ### The Data

# %%
# %%bigquery earnings_data
# SELECT *
# FROM crazy-hippo-01.earnings_ml.census_data
# Out:
# Query complete after 0.01s: 100%|██████████| 1/1 [00:00<00:00, 732.76query/s]
# Downloading: 100%|██████████| 32461/32461 [00:02<00:00, 15712.32rows/s]

# %%
earnings_data.head()
# Out:
#    age workclass  fnlwgt   education  education_num          marital_status  \
# 0   65         ?  293385   Preschool              1      Married-civ-spouse
# 1   64         ?  140237   Preschool              1      Married-civ-spouse
# 2   52         ?  248113   Preschool              1   Married-spouse-absent
# 3   54         ?  148657   Preschool              1      Married-civ-spouse
# 4   39         ?  362685   Preschool              1                 Widowed
#
#   occupation     relationship    race      sex  capital_gain  capital_loss  \
# 0          ?          Husband   Black     Male             0             0
# 1          ?          Husband   White     Male             0             0
# 2          ?   Other-relative   White     Male             0             0
# 3          ?             Wife   White   Female             0             0
# 4          ?    Not-in-family   White   Female             0             0
#
#    hours_per_week  native_country  income
# 0              30   United-States   <=50K
# 1              40   United-States   <=50K
# 2              40          Mexico   <=50K
# 3              40          Mexico   <=50K
# 4              20     El-Salvador   <=50K

# %% [markdown]
# ### Training a model in BigQuery ML

# %% [markdown]
# #### Using Logistic Regression for this example

# %%
# %%bigquery
# CREATE OR REPLACE MODEL earnings_ml.earnings_model
# OPTIONS(input_label_cols=['income'], model_type='logistic_reg')
# AS
# SELECT *
# FROM
#   `crazy-hippo-01.earnings_ml.census_data`
# Out:
# Query complete after 0.00s: 100%|██████████| 3/3 [00:00<00:00, 1270.62query/s]
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### The <b>ML.FEATURE_INFO</b> function allows you to see information about the input features used to train a model.

# %%
# %%bigquery
# SELECT *
# FROM ML.FEATURE_INFO(MODEL `crazy-hippo-01.earnings_ml.earnings_model`)
# Out:
# Query complete after 0.00s: 100%|██████████| 2/2 [00:00<00:00, 705.22query/s]
# Downloading: 100%|██████████| 14/14 [00:01<00:00,  8.77rows/s]
#              input      min        max           mean    median  \
# 0              age     17.0       90.0      38.580010      37.0
# 1        workclass      NaN        NaN            NaN       NaN
# 2           fnlwgt  13769.0  1484705.0  189622.921468  177305.0
# 3        education      NaN        NaN            NaN       NaN
# 4    education_num      1.0       16.0      10.074694      10.0
# 5   marital_status      NaN        NaN            NaN       NaN
# 6       occupation      NaN        NaN            NaN       NaN
# 7     relationship      NaN        NaN            NaN       NaN
# 8             race      NaN        NaN            NaN       NaN
# 9              sex      NaN        NaN            NaN       NaN
# 10    capital_gain      0.0    99999.0    1091.310981       0.0
# 11    capital_loss      0.0     4356.0      89.779949       0.0
# 12  hours_per_week      1.0       99.0      40.417802      40.0
# 13  native_country      NaN        NaN            NaN       NaN
#
#            stddev  category_count  null_count
# 0       13.667871             NaN         0.0
# 1             NaN             9.0         NaN
# 2   105574.934549             NaN         0.0
# 3             NaN            16.0         NaN
# 4        2.574967             NaN         0.0
# 5             NaN             7.0         NaN
# 6             NaN            15.0         NaN
# 7             NaN             6.0         NaN
# 8             NaN             5.0         NaN
# 9             NaN             2.0         NaN
# 10    7440.157104             NaN         0.0
# 11     409.005093             NaN         0.0
# 12      12.418299             NaN         0.0
# 13            NaN            42.0         NaN

# %% [markdown]
# #### Use the <b>ML.EVALUATE</b> function to evaluate model metrics.

# %%
# %%bigquery
# SELECT
#   *
# FROM
#   ML.EVALUATE(MODEL `crazy-hippo-01.earnings_ml.earnings_model`)
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 388.11query/s]
# Downloading: 100%|██████████| 1/1 [00:01<00:00,  1.55s/rows]
#    precision    recall  accuracy  f1_score  log_loss  roc_auc
# 0   0.709845  0.540434  0.838483  0.613662  0.347407   0.8898

# %% [markdown]
# #### Use the <b>ML.CONFUSION_MATRIX</b> function to return a confusion matrix for the given logistic regression model and input data.

# %%
# %%bigquery
# SELECT
#   *
# FROM
#   ML.CONFUSION_MATRIX(MODEL `crazy-hippo-01.earnings_ml.earnings_model`,
#   (
#     SELECT
#       *
#     FROM
#       `crazy-hippo-01.earnings_ml.census_data`))
# Out:
# Query complete after 0.00s: 100%|██████████| 4/4 [00:00<00:00, 1295.74query/s]
# Downloading: 100%|██████████| 2/2 [00:01<00:00,  1.26rows/s]
#   expected_label  ___50K  __50K
# 0          <=50K   23053   1588
# 1           >50K    3522   4298

# %% [markdown]
# #### The <b>ML.WEIGHTS</b> function allows you to see the underlying weights used by a model during prediction.

# %%
# %%bigquery
# SELECT *
# FROM ML.WEIGHTS(MODEL `crazy-hippo-01.earnings_ml.earnings_model`
# )
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 538.01query/s]
# Downloading: 100%|██████████| 15/15 [00:01<00:00,  9.48rows/s]
#    processed_input        weight  \
# 0              age  1.989957e-02
# 1        workclass           NaN
# 2           fnlwgt  3.201723e-07
# 3        education           NaN
# 4    education_num  1.239920e-01
# 5   marital_status           NaN
# 6       occupation           NaN
# 7     relationship           NaN
# 8             race           NaN
# 9              sex           NaN
# 10    capital_gain  4.762421e-05
# 11    capital_loss  4.775841e-04
# 12  hours_per_week  2.072122e-02
# 13  native_country           NaN
# 14   __INTERCEPT__ -3.207574e+00
#
#                                      category_weights
# 0                                                  []
# 1   [{'category': ' Local-gov', 'weight': -0.22264...
# 2                                                  []
# 3   [{'category': ' Assoc-acdm', 'weight': -0.1959...
# 4                                                  []
# 5   [{'category': ' Separated', 'weight': -0.60850...
# 6   [{'category': ' ?', 'weight': -0.4776070552043...
# 7   [{'category': ' Wife', 'weight': 0.92879077865...
# 8   [{'category': ' White', 'weight': -0.166867719...
# 9   [{'category': ' Male', 'weight': -0.0538525515...
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13  [{'category': ' El-Salvador', 'weight': -0.487...
# 14                                                 []

# %% [markdown]
# ## Batch Predictions

# %% [markdown]
# #### Let us generate som samples to predit on

# %%
# %%bigquery
# CREATE or REPLACE TABLE `earnings_ml.prediction_sample`
# AS (
# SELECT * EXCEPT(income)
# FROM `crazy-hippo-01.earnings_ml.census_data`
# WHERE RAND() < 0.0005
# )
# Out:
# Query complete after 0.00s: 100%|██████████| 3/3 [00:00<00:00, 1064.36query/s]
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Loading data from BQ and see how the data looks.

# %%
# %%bigquery prediction_data
# SELECT *
# FROM `crazy-hippo-01.earnings_ml.prediction_sample`
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 922.84query/s]
# Downloading: 100%|██████████| 13/13 [00:01<00:00,  7.83rows/s]

# %%
prediction_data
# Out:
#     age      workclass  fnlwgt      education  education_num  \
# 0    31        Private  339482        1st-4th              2
# 1    43        Private  193672        HS-grad              9
# 2    50        Private  228238        HS-grad              9
# 3    59   Self-emp-inc  200453        Masters             14
# 4    36      Local-gov  241998      Bachelors             13
# 5    28      Local-gov  180271      Bachelors             13
# 6    30        Private   54608   Some-college             10
# 7    20        Private  190227        Masters             14
# 8    40        Private  111829        Masters             14
# 9    26        Private   60722      Bachelors             13
# 10   26      Local-gov  104614      Bachelors             13
# 11   30        Private  297155   Some-college             10
# 12   20        Private   47791           12th              8
#
#          marital_status          occupation    relationship  \
# 0    Married-civ-spouse   Machine-op-inspct         Husband
# 1    Married-civ-spouse   Machine-op-inspct         Husband
# 2    Married-civ-spouse        Craft-repair         Husband
# 3    Married-civ-spouse               Sales         Husband
# 4    Married-civ-spouse      Prof-specialty         Husband
# 5    Married-civ-spouse   Handlers-cleaners         Husband
# 6    Married-civ-spouse   Machine-op-inspct         Husband
# 7         Never-married     Exec-managerial       Own-child
# 8         Never-married        Adm-clerical       Own-child
# 9         Never-married      Prof-specialty       Own-child
# 10        Never-married      Prof-specialty       Own-child
# 11             Divorced        Adm-clerical       Unmarried
# 12             Divorced       Other-service   Not-in-family
#
#                    race      sex  capital_gain  capital_loss  hours_per_week  \
# 0                 White     Male             0             0              40
# 1                 White     Male             0             0              40
# 2                 White     Male             0             0              40
# 3                 White     Male             0             0              40
# 4                 White     Male             0          1672              50
# 5                 White     Male             0             0              65
# 6                 White     Male             0             0              48
# 7                 White     Male             0             0              25
# 8                 White   Female             0             0              40
# 9    Asian-Pac-Islander   Female             0             0              40
# 10                White   Female             0             0              40
# 11                Black   Female             0             0              40
# 12                White   Female             0             0              10
#
#     native_country
# 0           Mexico
# 1    United-States
# 2    United-States
# 3    United-States
# 4    United-States
# 5    United-States
# 6    United-States
# 7    United-States
# 8    United-States
# 9    United-States
# 10   United-States
# 11   United-States
# 12   United-States

# %% [markdown]
# #### Batch Predictions

# %%
# %%bigquery
# SELECT *
# FROM
#   ML.PREDICT(MODEL `crazy-hippo-01.earnings_ml.earnings_model`,
#     (
#     SELECT
#       *
#     FROM
#       `crazy-hippo-01.earnings_ml.prediction_sample`))
# Out:
# Query complete after 0.00s: 100%|██████████| 2/2 [00:00<00:00, 1044.66query/s]
# Downloading: 100%|██████████| 13/13 [00:01<00:00,  9.78rows/s]
#    predicted_income                             predicted_income_probs  age  \
# 0             <=50K  [{'label': ' >50K', 'prob': 0.0456681564716456...   31
# 1             <=50K  [{'label': ' >50K', 'prob': 0.2325395975025235...   43
# 2             <=50K  [{'label': ' >50K', 'prob': 0.3166020444596405...   50
# 3              >50K  [{'label': ' >50K', 'prob': 0.827978478840053}...   59
# 4              >50K  [{'label': ' >50K', 'prob': 0.800726724717813}...   36
# 5             <=50K  [{'label': ' >50K', 'prob': 0.4655124567469922...   28
# 6             <=50K  [{'label': ' >50K', 'prob': 0.2578465300021020...   30
# 7             <=50K  [{'label': ' >50K', 'prob': 0.1599302900674899...   20
# 8             <=50K  [{'label': ' >50K', 'prob': 0.0941935476392710...   40
# 9             <=50K  [{'label': ' >50K', 'prob': 0.0754038692332926...   26
# 10            <=50K  [{'label': ' >50K', 'prob': 0.0787901222883414...   26
# 11            <=50K  [{'label': ' >50K', 'prob': 0.0304774635985267...   30
# 12            <=50K  [{'label': ' >50K', 'prob': 0.0072482840015292...   20
#
#         workclass  fnlwgt      education  education_num       marital_status  \
# 0         Private  339482        1st-4th              2   Married-civ-spouse
# 1         Private  193672        HS-grad              9   Married-civ-spouse
# 2         Private  228238        HS-grad              9   Married-civ-spouse
# 3    Self-emp-inc  200453        Masters             14   Married-civ-spouse
# 4       Local-gov  241998      Bachelors             13   Married-civ-spouse
# 5       Local-gov  180271      Bachelors             13   Married-civ-spouse
# 6         Private   54608   Some-college             10   Married-civ-spouse
# 7         Private  190227        Masters             14        Never-married
# 8         Private  111829        Masters             14        Never-married
# 9         Private   60722      Bachelors             13        Never-married
# 10      Local-gov  104614      Bachelors             13        Never-married
# 11        Private  297155   Some-college             10             Divorced
# 12        Private   47791           12th              8             Divorced
#
#             occupation    relationship                 race      sex  \
# 0    Machine-op-inspct         Husband                White     Male
# 1    Machine-op-inspct         Husband                White     Male
# 2         Craft-repair         Husband                White     Male
# 3                Sales         Husband                White     Male
# 4       Prof-specialty         Husband                White     Male
# 5    Handlers-cleaners         Husband                White     Male
# 6    Machine-op-inspct         Husband                White     Male
# 7      Exec-managerial       Own-child                White     Male
# 8         Adm-clerical       Own-child                White   Female
# 9       Prof-specialty       Own-child   Asian-Pac-Islander   Female
# 10      Prof-specialty       Own-child                White   Female
# 11        Adm-clerical       Unmarried                Black   Female
# 12       Other-service   Not-in-family                White   Female
#
#     capital_gain  capital_loss  hours_per_week  native_country
# 0              0             0              40          Mexico
# 1              0             0              40   United-States
# 2              0             0              40   United-States
# 3              0             0              40   United-States
# 4              0          1672              50   United-States
# 5              0             0              65   United-States
# 6              0             0              48   United-States
# 7              0             0              25   United-States
# 8              0             0              40   United-States
# 9              0             0              40   United-States
# 10             0             0              40   United-States
# 11             0             0              40   United-States
# 12             0             0              10   United-States
