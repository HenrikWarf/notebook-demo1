# %% [markdown]
# # Data Exploration

# %%
#Imports
# !pip install autoviz xlrd wordcloud
from autoviz.AutoViz_Class import AutoViz_Class
import pandas as pd
import numpy as np

# %%
#Data Load from BQ
# %%bigquery df
SELECT * FROM `crazy-hippo-01.census_data_us.census_raw` LIMIT 1000

# %%
df.head()
# Out:
#    age workclass  fnlwgt education  education_num      marital_status  \
# 0   39   Private  297847       9th              5  Married-civ-spouse
# 1   72   Private   74141       9th              5  Married-civ-spouse
# 2   45   Private  178215       9th              5  Married-civ-spouse
# 3   31   Private   86958       9th              5  Married-civ-spouse
# 4   55   Private  176012       9th              5  Married-civ-spouse
#
#           occupation relationship                race  gender  capital_gain  \
# 0      Other-service         Wife               Black  Female          3411
# 1    Exec-managerial         Wife  Asian-Pac-Islander  Female             0
# 2  Machine-op-inspct         Wife               White  Female             0
# 3    Exec-managerial         Wife               White  Female             0
# 4       Tech-support         Wife               White  Female             0
#
#    capital_loss  hours_per_week native_country  income_bracket
# ...

# %%
#Store table as CSV
df.to_csv('census.csv', index=False, header=True)

# %%
#Initiate AutoViz Class
AV = AutoViz_Class()

# %%
dft = AV.AutoViz(
    'census.csv',
    sep=",",
    depVar="income_bracket"
)
# Out:
# Shape of your Data Set loaded: (1000, 15)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  6
#     Number of String-Categorical Columns =  4
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  2
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  1
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  1
#     14 Predictors classified...
#         This does not include the Target column(s)
#         2 variables removed since they were ID or low-information variables
#
# ################ Binary_Classification VISUALIZATION Started #####################
# Total Number of Scatter Plots = 21
# Time to run AutoViz (in seconds) = 22.958
#
# ...
